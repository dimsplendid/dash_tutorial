# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
# Load Data
df = px.data.tips()
# Build App
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("JupyterDash Demo"),
    dcc.Graph(id='graph'),
    html.Label([
        "colorscale",
        dcc.Dropdown(
            id='colorscale-dropdown', clearable=False,
            value='plasma', options=[
                {'label': c, 'value': c}
                for c in px.colors.named_colorscales()
            ])
    ]),
])
# Define callback to update graph
@app.callback(
    Output('graph', 'figure'),
    [Input("colorscale-dropdown", "value")]
)
def update_figure(colorscale):
    return px.scatter(
        df, x="total_bill", y="tip", color="size",
        color_continuous_scale=colorscale,
        render_mode="webgl", title="Tips"
    )
app.run_server(mode='jupyterlab')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import plotly.express as px
#       2 from jupyter_dash import JupyterDash
#       3 import dash_core_components as dcc
#
# File D:\opt\anaconda\lib\site-packages\plotly\express\__init__.py:15
#       9 if pd is None:
#      10     raise ImportError(
#      11         """\
#      12 Plotly express requires pandas to be installed."""
#      13     )
# ---> 15 from ._imshow import imshow
#      16 from ._chart_types import (  # noqa: F401
#      17     scatter,
#      18     scatter_3d,
#    (...)
#      51     density_mapbox,
#      52 )
#      55 from ._core import (  # noqa: F401
#      56     set_mapbox_access_token,
#      57     defaults,
#      58     get_trendline_results,
#      59     NO_COLOR,
#      60 )
#
# File D:\opt\anaconda\lib\site-packages\plotly\express\_imshow.py:11
#       8 from plotly.utils import image_array_to_data_uri
#      10 try:
# ---> 11     import xarray
#      13     xarray_imported = True
#      14 except ImportError:
#
# File D:\opt\anaconda\lib\site-packages\xarray\__init__.py:1
# ----> 1 from . import testing, tutorial, ufuncs
#       2 from .backends.api import (
#       3     load_dataarray,
#       4     load_dataset,
#    (...)
#       8     save_mfdataset,
#       9 )
#      10 from .backends.rasterio_ import open_rasterio
#
# File D:\opt\anaconda\lib\site-packages\xarray\testing.py:8
#       4 from typing import Hashable, Set, Union
#       6 import numpy as np
# ----> 8 from xarray.core import duck_array_ops, formatting, utils
#       9 from xarray.core.dataarray import DataArray
#      10 from xarray.core.dataset import Dataset
#
# File D:\opt\anaconda\lib\site-packages\xarray\core\duck_array_ops.py:24
#      21 from numpy import take, tensordot, transpose, unravel_index  # noqa
#      22 from numpy import where as _where
# ---> 24 from . import dask_array_compat, dask_array_ops, dtypes, npcompat, nputils
#      25 from .nputils import nanfirst, nanlast
#      26 from .pycompat import (
#      27     cupy_array_type,
#      28     dask_array_type,
#    (...)
#      31     sparse_version,
#      32 )
#
# File D:\opt\anaconda\lib\site-packages\xarray\core\dask_array_compat.py:5
#       1 import warnings
#       3 import numpy as np
# ----> 5 from .pycompat import dask_version
#       7 try:
#       8     import dask.array as da
#
# File D:\opt\anaconda\lib\site-packages\xarray\core\pycompat.py:55
#      51     else:
#      52         return False
# ---> 55 dsk = DuckArrayModule("dask")
#      56 dask_version = dsk.version
#      57 dask_array_type = dsk.type
#
# File D:\opt\anaconda\lib\site-packages\xarray\core\pycompat.py:25, in DuckArrayModule.__init__(self, mod)
#      22 duck_array_version = LooseVersion(duck_array_module.__version__)
#      24 if mod == "dask":
# ---> 25     duck_array_type = (import_module("dask.array").Array,)
#      26 elif mod == "pint":
#      27     duck_array_type = (duck_array_module.Quantity,)
#
# File D:\opt\anaconda\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File D:\opt\anaconda\lib\site-packages\dask\array\__init__.py:2
#       1 try:
# ----> 2     from dask.array import backends, fft, lib, linalg, ma, overlap, random
#       3     from dask.array.blockwise import atop, blockwise
#       4     from dask.array.chunk_types import register_chunk_type
#
# File D:\opt\anaconda\lib\site-packages\dask\array\fft.py:8
#       6 try:
#       7     import scipy
# ----> 8     import scipy.fftpack
#       9 except ImportError:
#      10     scipy = None
#
# File D:\opt\anaconda\lib\site-packages\scipy\fftpack\__init__.py:94
#       1 """
#       2 =========================================================
#       3 Legacy discrete Fourier transforms (:mod:`scipy.fftpack`)
#    (...)
#      78
#      79 """
#      82 __all__ = ['fft','ifft','fftn','ifftn','rfft','irfft',
#      83            'fft2','ifft2',
#      84            'diff',
#    (...)
#      91            'dct', 'idct', 'dst', 'idst', 'dctn', 'idctn', 'dstn', 'idstn'
#      92            ]
# ---> 94 from .basic import *
#      95 from .pseudo_diffs import *
#      96 from .helper import *
#
# File D:\opt\anaconda\lib\site-packages\scipy\fftpack\basic.py:8
#       4 # Created by Pearu Peterson, August,September 2002
#       5 __all__ = ['fft','ifft','fftn','ifftn','rfft','irfft',
#       6            'fft2','ifft2']
# ----> 8 from scipy.fft import _pocketfft
#       9 from .helper import _good_shape
#      12 def fft(x, n=None, axis=-1, overwrite_x=False):
#
# File D:\opt\anaconda\lib\site-packages\scipy\fft\__init__.py:89
#      84 from ._basic import (
#      85     fft, ifft, fft2, ifft2, fftn, ifftn,
#      86     rfft, irfft, rfft2, irfft2, rfftn, irfftn,
#      87     hfft, ihfft, hfft2, ihfft2, hfftn, ihfftn)
#      88 from ._realtransforms import dct, idct, dst, idst, dctn, idctn, dstn, idstn
# ---> 89 from ._fftlog import fht, ifht, fhtoffset
#      90 from ._helper import next_fast_len
#      91 from ._backend import (set_backend, skip_backend, set_global_backend,
#      92                        register_backend)
#
# File D:\opt\anaconda\lib\site-packages\scipy\fft\_fftlog.py:11
#       9 from warnings import warn
#      10 from ._basic import rfft, irfft
# ---> 11 from ..special import loggamma, poch
#      13 __all__ = [
#      14     'fht', 'ifht',
#      15     'fhtoffset',
#      16 ]
#      19 # constants
#
# File D:\opt\anaconda\lib\site-packages\scipy\special\__init__.py:643
#       1 """
#       2 ========================================
#       3 Special functions (:mod:`scipy.special`)
#    (...)
#     638
#     639 """
#     641 from .sf_error import SpecialFunctionWarning, SpecialFunctionError
# --> 643 from . import _ufuncs
#     644 from ._ufuncs import *
#     646 from . import _basic
#
# File _ufuncs.pyx:1, in init scipy.special._ufuncs()
#
# ValueError: numpy.ndarray size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# !conda list
# Out:
# # packages in environment at D:\opt\anaconda\envs\dash_tutorial:
# #
# # Name                    Version                   Build  Channel
# ansi2html                 1.8.0                    pypi_0    pypi
# asttokens                 2.2.1                    pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# ca-certificates           2023.01.10           haa95532_0
# certifi                   2022.12.7        py38haa95532_0
# charset-normalizer        3.0.1                    pypi_0    pypi
# click                     8.1.3                    pypi_0    pypi
# colorama                  0.4.6                    pypi_0    pypi
# comm                      0.1.2                    pypi_0    pypi
# dash                      2.8.1                    pypi_0    pypi
# dash-core-components      2.0.0                    pypi_0    pypi
# dash-html-components      2.0.0                    pypi_0    pypi
# dash-table                5.0.0                    pypi_0    pypi
# debugpy                   1.6.6                    pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# executing                 1.2.0                    pypi_0    pypi
# flask                     2.2.3                    pypi_0    pypi
# idna                      3.4                      pypi_0    pypi
# importlib-metadata        6.0.0                    pypi_0    pypi
# ipykernel                 6.21.2                   pypi_0    pypi
# ipython                   8.11.0                   pypi_0    pypi
# itsdangerous              2.1.2                    pypi_0    pypi
# jedi                      0.18.2                   pypi_0    pypi
# jinja2                    3.1.2                    pypi_0    pypi
# jupyter-client            8.0.3                    pypi_0    pypi
# jupyter-core              5.2.0                    pypi_0    pypi
# jupyter-dash              0.4.2                    pypi_0    pypi
# libffi                    3.4.2                hd77b12b_6
# markupsafe                2.1.2                    pypi_0    pypi
# matplotlib-inline         0.1.6                    pypi_0    pypi
# nest-asyncio              1.5.6                    pypi_0    pypi
# openssl                   1.1.1t               h2bbff1b_0
# packaging                 23.0                     pypi_0    pypi
# parso                     0.8.3                    pypi_0    pypi
# pickleshare               0.7.5                    pypi_0    pypi
# pip                       22.3.1           py38haa95532_0
# platformdirs              3.0.0                    pypi_0    pypi
# plotly                    5.13.1                   pypi_0    pypi
# prompt-toolkit            3.0.38                   pypi_0    pypi
# psutil                    5.9.4                    pypi_0    pypi
# pure-eval                 0.2.2                    pypi_0    pypi
# pygments                  2.14.0                   pypi_0    pypi
# python                    3.8.16               h6244533_2
# python-dateutil           2.8.2                    pypi_0    pypi
# pywin32                   305                      pypi_0    pypi
# pyzmq                     25.0.0                   pypi_0    pypi
# requests                  2.28.2                   pypi_0    pypi
# retrying                  1.3.4                    pypi_0    pypi
# setuptools                65.6.3           py38haa95532_0
# six                       1.16.0                   pypi_0    pypi
# sqlite                    3.40.1               h2bbff1b_0
# stack-data                0.6.2                    pypi_0    pypi
# tenacity                  8.2.2                    pypi_0    pypi
# tornado                   6.2                      pypi_0    pypi
# traitlets                 5.9.0                    pypi_0    pypi
# urllib3                   1.26.14                  pypi_0    pypi
# vc                        14.2                 h21ff451_1
# vs2015_runtime            14.27.29016          h5e58377_2
# wcwidth                   0.2.6                    pypi_0    pypi
# werkzeug                  2.2.3                    pypi_0    pypi
# wheel                     0.38.4           py38haa95532_0
# wincertstore              0.2              py38haa95532_2
# zipp                      3.15.0                   pypi_0    pypi
